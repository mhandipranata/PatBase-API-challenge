# %% [markdown]
# # Patent Data Extraction

# %% [markdown]
# ## Extract - Patent Data from PatBase API

# %% [markdown]
# PatBase is a patent database for patent search and analysis platform with worldwide coverage.
# PatBase has a REST API paid license which use to extract patent data information, e.g. priority, publication date, family member, patent status, legal status, assignee, inventor, etc.
#
# PatBase REST API Documentation: http://www.patbase.com/rest/PatBaseRestAPI.pdf
#
# Here I will extract couple of patent informations with API call to PatBase.
# License is necessary for PatBase UI access and API request.

# %%
# Dependencies
import re, json
import requests
import pandas as pd
import codecs
from config_patbase import user_name, enter_key

# %%
# PatBase API
# headers = {
#     'method': 'login',
#     'userid': user_name,
#     'password': enter_key
# }

login_url = f"https://www.patbase.com/rest/api.php?method=login&userid={user_name}&password={enter_key}"
session_response = requests.get(login_url)
# session_response
# session_response = requests.post(login_url, headers=headers)
# session_response_json = session_response.json()
# print(json.dumps(session_response_json, indent = 4))
# decoded_response = session_response.text
# decoded_response

# session_response_json = json.loads(session_response)
# print(session_response_json)
# print(json.dumps(session_response, indent = 4))
# resp_parsed = re.sub(r'^jsonp\d+\(|\)\s+$', '', session_response.content.decode('utf-8-sig'))
# resp_parsed
# data = json.loads(resp_parsed.read())
# print(data)
# session_response_json = session_response.json()
# decoded_response = session_response.content.decode('utf-8-sig')
# # .replace('\0', '')
# data = json.loads(decoded_response)
# print(data)
decoded_response = codecs.decode(session_response.text.encode(), 'utf-8-sig')
data = json.loads(decoded_response)
print(data)
authorization_code = session_response.headers['Set-Cookie']
print(authorization_code)
# decoded_response = session_response.text.encode().decode('utf-8-sig') 
# decoded_response
# Out:
# {'LOGIN_TO_API': 'OK'}
# SessionFarm_GUID=%7B8B9B8B5E-4699-4488-B52A-07B9B44311E1%7D; path=/, OGSession=2aede6a8c2fc5207e21204bc85b8e5b35d008cf9e9a3adf8bc00c74eba725e85;Path=/;Domain=www.patbase.com, visid_incap_9867=0vOC7YLQS+mUDiisHkU1JMhG8F4AAAAAQUIPAAAAAACzRS6CX4jgbzaurAWs8l7m; expires=Mon, 21 Jun 2021 06:59:59 GMT; HttpOnly; path=/; Domain=.patbase.com, nlbi_9867=CHxWQ1ZfIAxgAO8ohoeo8gAAAAAW81wVxrOVvQBsh9EsZXJD; path=/; Domain=.patbase.com, incap_ses_568_9867=mgtkJC/jYBx/sevsBvHhB8hG8F4AAAAAKdYRT0KG6JeKC60w/djzSw==; path=/; Domain=.patbase.com

# %%
# Access PatBase API using username and password
login_url = f"https://www.patbase.com/rest/api.php?method=login&userid={user_name}&password={enter_key}"
session_response = requests.Session().get(login_url)

# Extract the cookies from the requests session to requests data later
cookiejar = session_response.cookies.get_dict()
print(cookiejar)
# Out:
# {'incap_ses_567_9867': 'QVpVSv3anHhQAzmXkWPeB4Up+V4AAAAAfaEkEcL7kwo4Cntze4FiHQ==', 'nlbi_9867': 'kwrlRWUhaAhOAwwXhoeo8gAAAABrbE16gVktnrnjx7wMzJ7r', 'visid_incap_9867': 'YAGaSbFSRbmXNOOLXhvQSoQp+V4AAAAAQUIPAAAAAACZPCED/oJFFTDuGLjjJnHJ', 'OGSession': '637b0c70ff77678a2b61973cd5900fa90bf61be4847312b8fd6e64686239ed5a', 'SessionFarm_GUID': '%7B16B3E551-9285-47CD-A36B-3F1B59B11EA6%7D'}

# %% [markdown]
# ### GetMember
# This method is used to get more information on a single member of a family, be it a publication or an
# application document. This method requires authorization.
# Usage
#
# URL:
# https://www.patbase.com/rest/api.php?method=getmember&pn=[Patent Number]&kd=[Kind
# Code*]&ft=[True/False*]&legal=[True/False*]
#
# All values marked with * are optional, you do not need to include the values in the request if they
# are unwanted.

# %%
# Requests GetMember data and input the cookies we got earlier
# Test run for one patent (Example: pn=IN245512)
url = 'https://www.patbase.com/rest/api.php?method=getmember&pn=IN245512'
requests_jar = requests.cookies.RequestsCookieJar()
requests_jar.set('SessionFarm_GUID', cookiejar['SessionFarm_GUID'])

response = requests.get(url, cookies=requests_jar)
decoded_response = codecs.decode(response.text.encode(), 'utf-8-sig')
data = json.loads(decoded_response)
print(json.dumps(data, indent=4))
# Out:
# {
#     "Family": 32619612,
#     "Publications": [
#         {
#             "PN": "IN245512",
#             "KD": "B",
#             "CC": "IN",
#             "PD": "20110128",
#             "AN": "IN2007CN01024",
#             "AD": "20070309",
#             "UE": "1105",
#             "IMG": 0,
#             "DA": "ALIVE"
#         }
#     ],
#     "Priorities": [
#         {
#             "PR": "JP20040234884",
#             "PRD": "20040811"
#         },
#         {
#             "PR": "WO2005JP14756",
#             "PRD": "20050811"
#         }
#     ],
#     "IPC": [],
#     "CPC": [],
#     "USC": [],
#     "Assignees": [
#         {
#             "PA": "NTT DOCOMO INC",
#             "CCOR": "",
#             "STD": "N"
#         }
#     ],
#     "Inventors": [
#         {
#             "INV": "NAKAMURA TAKEHIRO",
#             "CCOR": "",
#             "STD": "N"
#         },
#         {
#             "INV": "UMESH ANIL",
#             "CCOR": "",
#             "STD": "N"
#         },
#         {
#             "INV": "USUDA MASAFUMI",
#             "CCOR": "",
#             "STD": "N"
#         }
#     ],
#     "Agent": [],
#     "ForwardCitations": [],
#     "BackwardCitations": [],
#     "LegalStatus": [],
#     "DesignatedStates": [],
#     "ProbableAssignee": "NTT DOCOMO INC",
#     "Title": "MOBILE COMMUNICATION SYSTEM FOR PACKET TRANSMISSION SCHEME BETWEEN A MOBILE STATION AND A BASE STATION",
#     "Abstract": "The present invention relates to a mobile communication system which applies a high-speed downlink packet transmission scheme (HSDPA scheme) in a downlink and an enhanced uplink packet transmission scheme (EUL scheme) in an uplink between a mobile station and a base station. In the mobile communication system according to the present invention, a serving cell in the high-speed downlink packet transmission scheme for a specified mobile station and a serving cell in the enhanced uplink packet transmission scheme for the specified mobile station are modified so as to become the same cell.",
#     "FullText": []
# }

# %%
patbase_family_number  = data["Family"]
patent_number = data["Publications"][0]["PN"]
application_number = data["Publications"][0]["AN"]
kind_code = data["Publications"][0]["KD"]

print(patbase_family_number)
print(patent_number)
print(application_number)
print(kind_code)
# Out:
# 32619612
# IN245512
# IN2007CN01024
# B

# %%
# List of patent/application numbers to be searched/requested are saved in a csv file, so read csv
patent_df = pd.read_csv("patent_list_to_request.csv")
patent_df = patent_df.rename(columns={"current_patent_number ": "current_patent_number"})
patent_df["country_and_patent_number"] = patent_df["country"] + patent_df["current_patent_number"].astype(str)
patent_df
# Out:
#     country  current_patent_number country_and_patent_number
# 0        JP                3174742                 JP3174742
# 1        JP                3215114                 JP3215114
# 2        JP                3236849                 JP3236849
# 3        JP                3236851                 JP3236851
# 4        JP                3236852                 JP3236852
# ..      ...                    ...                       ...
# 175      RU                2619171                 RU2619171
# 176      RU                2636013                 RU2636013
# 177      RU                2642477                 RU2642477
# 178      RU                2669792                 RU2669792
# 179      RU                2675071                 RU2675071
#
# [180 rows x 3 columns]

# %%
patent_list = patent_df["country_and_patent_number"].to_list()
print(patent_list)
# Out:
# ['JP3174742', 'JP3215114', 'JP3236849', 'JP3236851', 'JP3236852', 'JP3276353', 'JP3276354', 'JP3293819', 'JP3625055', 'JP3638940', 'JP3640660', 'JP3644642', 'JP3673757', 'JP3675433', 'JP3711263', 'JP3712422', 'JP3857629', 'JP3924578', 'JP3968073', 'JP3997253', 'JP4002591', 'JP4017658', 'JP4021761', 'JP4027310', 'JP4051338', 'JP4091642', 'JP4098717', 'JP4197839', 'JP4212654', 'JP4271200', 'JP4278662', 'JP4280642', 'JP4283285', 'JP4284324', 'JP4309767', 'JP4319983', 'JP4342109', 'JP4382754', 'JP4439543', 'JP4465360', 'JP4469602', 'JP4504410', 'JP4518508', 'JP4528830', 'JP4567718', 'JP4576415', 'JP4595912', 'JP4602422', 'JP4602431', 'JP4612637', 'JP4650978', 'JP4650994', 'JP4658152', 'JP4660672', 'JP4663008', 'JP4663011', 'JP4669946', 'JP4669947', 'JP4674303', 'JP4681656', 'JP4693942', 'JP4729077', 'JP4742113', 'JP4742117', 'JP4748737', 'JP4749450', 'JP4772823', 'JP4783402', 'JP4801696', 'JP4806028', 'JP4838840', 'JP4847679', 'JP4856723', 'JP4877841', 'JP4881799', 'JP4896073', 'JP4971445', 'JP4979632', 'JP5011439', 'JP5017559', 'JP5045839', 'JP5054772', 'JP5057459', 'JP5087479', 'JP5140227', 'JP5158276', 'JP5193315', 'JP5234377', 'JP5375954', 'JP5477487', 'JP5510332', 'JP5525092', 'JP5598564', 'JP5606603', 'JP5684323', 'JP5773074', 'JP5825789', 'JP5841566', 'JP5896083', 'JP5926433', 'JP5943180', 'JP6025232', 'JP6044799', 'JP6214052', 'JP6308279', 'JP6460209', 'JP6501084', 'KR100556591', 'KR100559925', 'KR100561114', 'KR100588389', 'KR100588390', 'KR100694339', 'KR100772134', 'KR100782625', 'KR100815636', 'KR100845821', 'KR100892658', 'KR100912972', 'KR100923923', 'KR100927982', 'KR100928250', 'KR100944236', 'KR100945613', 'KR100947530', 'KR100953151', 'KR100954001', 'KR100954820', 'KR100958330', 'KR100959291', 'KR100960747', 'KR100965532', 'KR100977452', 'KR100977453', 'KR100978320', 'KR100978826', 'KR100980102', 'KR100981628', 'KR100985645', 'KR101004695', 'KR101005046', 'KR101009137', 'KR101018434', 'KR101018446', 'KR101018449', 'KR101045449', 'KR101050335', 'KR101051094', 'KR101061473', 'KR101086796', 'KR101089448', 'KR101120380', 'KR101132033', 'KR101133868', 'KR101153598', 'KR101226801', 'KR101287322', 'KR101289206', 'KR101344111', 'KR101398950', 'KR101401605', 'KR101430676', 'KR101539872', 'KR101589885', 'KR101651807', 'KR101652651', 'KR101663451', 'KR101779458', 'KR102028271', 'RU2213367', 'RU2237370', 'RU2503141', 'RU2546301', 'RU2600131', 'RU2602088', 'RU2619171', 'RU2636013', 'RU2642477', 'RU2669792', 'RU2675071']

# %%
# List of patent/application numbers to be searched
patent_list = ['JP3174742', 'JP3215114', 'JP3236849']

requests_jar = requests.cookies.RequestsCookieJar()
requests_jar.set('SessionFarm_GUID', cookiejar['SessionFarm_GUID'])

# Using for loop we will request the patent data information 
# (PatBase family number, patent number, application number, kind code)

family_number_list = []
patent_number_list = []
application_number_list = []
kind_code_list = []

for patent in patent_list:
    url = f'https://www.patbase.com/rest/api.php?method=getmember&pn={patent}'
    response = requests.get(url, cookies=requests_jar)
    decoded_response = codecs.decode(response.text.encode(), 'utf-8-sig')
    data = json.loads(decoded_response)
    
    family_number_list.append(data["Family"])
    patent_number_list.append(data["Publications"][0]["PN"])
    application_number_list.append(data["Publications"][0]["AN"])
    kind_code_list.append(data["Publications"][0]["KD"])
    
print(family_number_list)
print(patent_number_list)
print(application_number_list)
print(kind_code_list)
# Out:
# [4303673, 7417628, 7464150]
# ['JP3174742', 'JP3215114', 'JP3236849']
# ['JP19900158886', 'JP19900009567', 'JP19890280068']
# ['A2', 'A2', 'A2']

# %%
# Requests GetMember data and input the cookies we got earlier
# Test run for one patent (Example: pn=JP3174742)
url = 'https://www.patbase.com/rest/api.php?method=getmember&pn=JP3174742'
requests_jar = requests.cookies.RequestsCookieJar()
requests_jar.set('SessionFarm_GUID', cookiejar['SessionFarm_GUID'])

response = requests.get(url, cookies=requests_jar)
decoded_response = codecs.decode(response.text.encode(), 'utf-8-sig')
data = json.loads(decoded_response)
print(json.dumps(data, indent=4))
# Out:
# {
#     "Family": 4303673,
#     "Publications": [
#         {
#             "PN": "JP3174742",
#             "KD": "A2",
#             "CC": "JP",
#             "PD": "19910729",
#             "AN": "JP19900158886",
#             "AD": "19900619",
#             "UE": "",
#             "IMG": 1,
#             "DA": "DEAD"
#         }
#     ],
#     "Priorities": [
#         {
#             "PR": "US19890368481",
#             "PRD": "19890619"
#         }
#     ],
#     "IPC": [
#         "H01L21/02",
#         "H01L21/48",
#         "H01L23/12",
#         "H01L23/48",
#         "H01L23/498",
#         "H01L23/50"
#     ],
#     "CPC": [
#         "H01L21/4846",
#         "H01L23/49822",
#         "H01L2924/0002",
#         "Y10T29/4914",
#         "Y10T29/49151",
#         "Y10T29/49169"
#     ],
#     "USC": [],
#     "Assignees": [
#         {
#             "PA": "DU PONT",
#             "CCOR": "",
#             "STD": "Y"
#         },
#         {
#             "PA": "E I DU PONT DE NEMOURS AND CO",
#             "CCOR": "",
#             "STD": "N"
#         }
#     ],
#     "Inventors": [
#         {
#             "INV": "JIYON UOORUTAA ROTSUTO",
#             "CCOR": "",
#             "STD": "Y"
#         },
#         {
#             "INV": "PATORITSUKU UOORUTAA UORESU",
#             "CCOR": "",
#             "STD": "Y"
#         },
#         {
#             "INV": "TOMASU REIMONDO POURIN",
#             "CCOR": "",
#             "STD": "Y"
#         },
#         {
#             "INV": "\u30b8\u30e8\u30f3\u30fb\u30a6\u30aa\u30fc\u30eb\u30bf\u30fc\u30fb\u30ed\u30c4\u30c8",
#             "CCOR": "",
#             "STD": "N"
#         },
#         {
#             "INV": "\u30c8\u30de\u30b9\u30fb\u30ec\u30a4\u30e2\u30f3\u30c9\u30fb\u30dd\u30a6\u30ea\u30f3",
#             "CCOR": "",
#             "STD": "N"
#         },
#         {
#             "INV": "\u30d1\u30c8\u30ea\u30c4\u30af\u30fb\u30a6\u30aa\u30fc\u30eb\u30bf\u30fc\u30fb\u30a6\u30aa\u30ec\u30b9",
#             "CCOR": "",
#             "STD": "N"
#         }
#     ],
#     "Agent": [],
#     "ForwardCitations": [
#         {
#             "PN": "JP2008126447",
#             "KD": "A1",
#             "Year": "2010"
#         },
#         {
#             "PN": "JP5354380",
#             "KD": "B2",
#             "Year": "2013"
#         },
#         {
#             "PN": "JP5354380",
#             "KD": "B1",
#             "Year": "2013"
#         }
#     ],
#     "BackwardCitations": [],
#     "LegalStatus": [],
#     "DesignatedStates": [],
#     "ProbableAssignee": "DU PONT",
#     "Title": "CHIP CARRIER PACKAGE AND ITS MANUFACTURE",
#     "Abstract": "PURPOSE: To connect the uppermost conductive layer to a first conductive layer, without using punching tools by providing a first electrical conductor that is terminated, while being adjacent to the side wall part of a receptacle, a first insulating layer that faces the one side, and a second conductor that is connected to the first electrical conductor. CONSTITUTION: A dielectric layer 16 is provided at a lower part between conductive planes 14 of four layers. Dielectric paths are mutually connected by a series of cross connection vias 15, that are formed through a dielectric layer 16 up to the conductive path, located on a layer 18 on the uppermost surface of a base 12. A signal layer 20 of a package 10 is arranged, so that it forms a shelf 22 for exposing a selective contact pad 19. A grounding on the signal layer 20 and a terminal 23 of a power pad 25 are extended onto a cavity being formed at a dielectric layer of the signal layer 20 and is deformed, so that it is subjected to junction connection with the contact pad 19 being exposed on the shelf 22 of the layer 18 on the uppermost surface of the base 12, thus establishing inter connection from the signal layer of the uppermost part to a layer directly below.",
#     "FullText": []
# }

# %% [markdown]
# ### Query
#
# This method is used to run a query on the PatBase Database, authorization is required for this
# method.
#
# URL:
# https://www.patbase.com/rest/api.php?method=query&query=[PatBaseQuery]

# %%
# Requests Query data and input the cookies we got earlier
# Test run for one patent 
q_url = 'https://www.patbase.com/rest/api.php?method=query&query=PN%3DJP3174742'
requests_jar = requests.cookies.RequestsCookieJar()
requests_jar.set('SessionFarm_GUID', cookiejar['SessionFarm_GUID'])

q_response = requests.get(q_url, cookies=requests_jar)
decoded_q_response = codecs.decode(q_response.text.encode(), 'utf-8-sig')
q_results = json.loads(decoded_q_response)
print(json.dumps(q_results, indent=4))
# Out:
# {
#     "Results": "3",
#     "QueryKey": "{16B3E551-9285-47CD-A36B-3F1B59B11EA6}_API_rad73480.tmp16168.14"
# }

# %% [markdown]
# ### SearchResultsBIB
#
# This method is used to get the bibliographic information of a search result. This method requires
# authorization.
#
# URL:
# https://www.patbase.com/rest/api.php?method=searchresultsbib&querykey=[QueryKey]&s
# ortorder=[sortorder*]&from=[from*]&to=[to*]
#
# All values marked with * are optional, you do not need to include the values in the request if they
# are unwanted.

# %%
# With the QueryKey we can extract the patent data information we need
# We will extract patents' bibliographic information

query_key = q_results["QueryKey"]
bib_url = f'https://www.patbase.com/rest/api.php?method=searchresultsbib&querykey={query_key}'
requests_jar = requests.cookies.RequestsCookieJar()
requests_jar.set('SessionFarm_GUID', cookiejar['SessionFarm_GUID'])

bib_response = requests.get(bib_url, cookies=requests_jar)
decoded_bib_response = codecs.decode(bib_response.text.encode(), 'utf-8-sig')
bib_results = json.loads(decoded_bib_response)
print(json.dumps(bib_results, indent=4))
# Out:
# {
#     "Families": [
#         {
#             "Record": "1",
#             "Family": "33528013",
#             "PatentNumber": "JP10232696A",
#             "ProbableAssignee": "MATSUSHITA ELECTRIC IND CO LTD",
#             "FirstInventor": "YASUNAGA KAZUTOSHI",
#             "Publications": [
#                 {
#                     "PN": "JP10232696",
#                     "KD": "A2",
#                     "CC": "JP",
#                     "PD": "19980902",
#                     "AN": "JP19970034582",
#                     "AD": "19970219",
#                     "UE": "",
#                     "IMG": 4
#                 },
#                 {
#                     "PN": "JP3174742",
#                     "KD": "B2",
#                     "CC": "JP",
#                     "PD": "20010611",
#                     "AN": "JP19970034582",
#                     "AD": "19970219",
#                     "UE": "",
#                     "IMG": 13
#                 }
#             ],
#             "Priorities": [
#                 {
#                     "PR": "VLF28167684",
#                     "PRD": ""
#                 },
#                 {
#                     "PR": "JP19970034582",
#                     "PRD": "19970219"
#                 }
#             ],
#             "IPC": [
#                 "G10L19/00",
#                 "G10L19/08",
#                 "G10L19/12",
#                 "H03M7/30",
#                 "H03M7/32",
#                 "H03M7/34",
#                 "H04B14/04"
#             ],
#             "CPC": [],
#             "USC": [],
#             "Assignees": [
#                 {
#                     "PA": "MATSUSHITA ELECTRIC IND CO LTD",
#                     "STD": "Y",
#                     "CCOR": ""
#                 },
#                 {
#                     "PA": "MATSUSHITA ELECTRIC INDUSTRIAL CO LTD",
#                     "STD": "N",
#                     "CCOR": ""
#                 },
#                 {
#                     "PA": "PANASONIC CORP",
#                     "STD": "N",
#                     "CCOR": ""
#                 }
#             ],
#             "Inventors": [
#                 {
#                     "INV": "EBARA HIROYUKI",
#                     "STD": "Y",
#                     "CCOR": ""
#                 },
#                 {
#                     "INV": "MORII TOSHIYUKI",
#                     "STD": "Y",
#                     "CCOR": ""
#                 },
#                 {
#                     "INV": "YASUNAGA KAZUTOSHI",
#                     "STD": "Y",
#                     "CCOR": ""
#                 }
#             ],
#             "Title": "VOICE SOURCE VECTOR GENERATING DEVICE AND VOICE CODING/ DECODING DEVICE",
#             "Abstract": "JP10232696A  PROBLEM TO BE SOLVED: To make possible performing noise code book retrieval at a calculation cost nearly equal to the case using an algebraic structural voice source as a noise code book and obtaining a high quality synthetic voice in a voice source vector generating device and a voice coding/decoding device efficiently compression coding/decoding voice information. SOLUTION: The voice vector generating device makes possible storing (11) plural pieces of fixed waveforms, arranging (12) respective fixed waveforms to respective start end positions based on start end candidate positional information, adding (13) these fixed waveforms, generating a voice source vector (14) and generating the voice source vector close to a rear voice. Further, by constituting a CELP(code excited linear prediction) type voice coding/decoding device using the voice source vector generating device as the noise code book, the quality in the synthetic voice is improved at the calculation cost nearly equal to the case using the algebraic structural voice source as the noise code book."
#         },
#         {
#             "Record": "2",
#             "Family": "51062060",
#             "PatentNumber": "JP3174742U",
#             "ProbableAssignee": "YANG FUMIHIRO",
#             "FirstInventor": "",
#             "Publications": [
#                 {
#                     "PN": "JP3174742",
#                     "KD": "U",
#                     "CC": "JP",
#                     "PD": "20120405",
#                     "AN": "JP20120000304U",
#                     "AD": "20120124",
#                     "UE": "1218",
#                     "IMG": 0
#                 }
#             ],
#             "Priorities": [
#                 {
#                     "PR": "JP20120000304U",
#                     "PRD": "20120124"
#                 }
#             ],
#             "IPC": [
#                 "G01B7/00",
#                 "G01B7/30",
#                 "G01D5/165"
#             ],
#             "CPC": [],
#             "USC": [],
#             "Assignees": [
#                 {
#                     "PA": "YANG FUMIHIRO",
#                     "STD": "N",
#                     "CCOR": ""
#                 }
#             ],
#             "Inventors": [],
#             "Title": "Structure potentiometer",
#             "Abstract": ""
#         },
#         {
#             "Record": "3",
#             "Family": "4303673",
#             "PatentNumber": "US4965702A",
#             "ProbableAssignee": "DU PONT",
#             "FirstInventor": "JIYON UOORUTAA ROTSUTO",
#             "Publications": [
#                 {
#                     "PN": "EP0403992",
#                     "KD": "A2",
#                     "CC": "EP",
#                     "PD": "19901227",
#                     "AN": "EP19900111407",
#                     "AD": "19900616",
#                     "UE": "",
#                     "IMG": 1
#                 },
#                 {
#                     "PN": "EP0403992",
#                     "KD": "A3",
#                     "CC": "EP",
#                     "PD": "19921230",
#                     "AN": "EP19900111407",
#                     "AD": "19900616",
#                     "UE": "",
#                     "IMG": 0
#                 },
#                 {
#                     "PN": "JP3174742",
#                     "KD": "A2",
#                     "CC": "JP",
#                     "PD": "19910729",
#                     "AN": "JP19900158886",
#                     "AD": "19900619",
#                     "UE": "",
#                     "IMG": 1
#                 },
#                 {
#                     "PN": "US4965702",
#                     "KD": "A",
#                     "CC": "US",
#                     "PD": "19901023",
#                     "AN": "US19890368481",
#                     "AD": "19890619",
#                     "UE": "",
#                     "IMG": 1
#                 }
#             ],
#             "Priorities": [
#                 {
#                     "PR": "US19890368481",
#                     "PRD": "19890619"
#                 }
#             ],
#             "IPC": [
#                 "H01L21/02",
#                 "H01L21/48",
#                 "H01L23/12",
#                 "H01L23/48",
#                 "H01L23/498",
#                 "H01L23/50"
#             ],
#             "CPC": [
#                 "H01L21/4846",
#                 "H01L23/49822",
#                 "H01L2924/0002",
#                 "Y10T29/4914",
#                 "Y10T29/49151",
#                 "Y10T29/49169"
#             ],
#             "USC": [
#                 "257/692",
#                 "257/698",
#                 "257/E23.062",
#                 "29/838",
#                 "29/844",
#                 "29/854",
#                 "361/401",
#                 "361/406",
#                 "361/408",
#                 "361/414",
#                 "361/764",
#                 "361/774",
#                 "361/776",
#                 "361/792"
#             ],
#             "Assignees": [
#                 {
#                     "PA": "DU PONT",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 },
#                 {
#                     "PA": "E I DU PONT DE NEMOURS AND CO",
#                     "STD": "N",
#                     "CCOR": ""
#                 },
#                 {
#                     "PA": "E I DU PONT DE NEMOURS AND COMPANY",
#                     "STD": "N",
#                     "CCOR": ""
#                 },
#                 {
#                     "PA": "EI DU PONT DE NEMOURS AND CO",
#                     "STD": "N",
#                     "CCOR": ""
#                 }
#             ],
#             "Inventors": [
#                 {
#                     "INV": "JIYON UOORUTAA ROTSUTO",
#                     "STD": "Y",
#                     "CCOR": ""
#                 },
#                 {
#                     "INV": "LOTT JOHN W",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 },
#                 {
#                     "INV": "LOTT JOHN WALTER",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 },
#                 {
#                     "INV": "PATORITSUKU UOORUTAA UORESU",
#                     "STD": "Y",
#                     "CCOR": ""
#                 },
#                 {
#                     "INV": "POULIN THOMAS R",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 },
#                 {
#                     "INV": "POULIN THOMAS RAYMOND",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 },
#                 {
#                     "INV": "TOMASU REIMONDO POURIN",
#                     "STD": "Y",
#                     "CCOR": ""
#                 },
#                 {
#                     "INV": "WALLACE PATRICK W",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 },
#                 {
#                     "INV": "WALLACE PATRICK WALTER",
#                     "STD": "Y",
#                     "CCOR": "US"
#                 }
#             ],
#             "Title": "CHIP CARRIER PACKAGE AND METHOD OF MANUFACTURE",
#             "Abstract": "US4965702A  An improved integrated chip carrier package contains closely spaced electrical leads which facilitates contact with leads from the chip."
#         }
#     ]
# }

# %%
bib_results["Families"][0]
# Out:
# {'Record': '1',
#  'Family': '33528013',
#  'PatentNumber': 'JP10232696A',
#  'ProbableAssignee': 'MATSUSHITA ELECTRIC IND CO LTD',
#  'FirstInventor': 'YASUNAGA KAZUTOSHI',
#  'Publications': [{'PN': 'JP10232696',
#    'KD': 'A2',
#    'CC': 'JP',
#    'PD': '19980902',
#    'AN': 'JP19970034582',
#    'AD': '19970219',
#    'UE': '',
#    'IMG': 4},
#   {'PN': 'JP3174742',
#    'KD': 'B2',
#    'CC': 'JP',
#    'PD': '20010611',
#    'AN': 'JP19970034582',
#    'AD': '19970219',
#    'UE': '',
#    'IMG': 13}],
#  'Priorities': [{'PR': 'VLF28167684', 'PRD': ''},
#   {'PR': 'JP19970034582', 'PRD': '19970219'}],
#  'IPC': ['G10L19/00',
#   'G10L19/08',
#   'G10L19/12',
#   'H03M7/30',
#   'H03M7/32',
#   'H03M7/34',
#   'H04B14/04'],
#  'CPC': [],
#  'USC': [],
#  'Assignees': [{'PA': 'MATSUSHITA ELECTRIC IND CO LTD',
#    'STD': 'Y',
#    'CCOR': ''},
#   {'PA': 'MATSUSHITA ELECTRIC INDUSTRIAL CO LTD', 'STD': 'N', 'CCOR': ''},
#   {'PA': 'PANASONIC CORP', 'STD': 'N', 'CCOR': ''}],
#  'Inventors': [{'INV': 'EBARA HIROYUKI', 'STD': 'Y', 'CCOR': ''},
#   {'INV': 'MORII TOSHIYUKI', 'STD': 'Y', 'CCOR': ''},
#   {'INV': 'YASUNAGA KAZUTOSHI', 'STD': 'Y', 'CCOR': ''}],
#  'Title': 'VOICE SOURCE VECTOR GENERATING DEVICE AND VOICE CODING/ DECODING DEVICE',
#  'Abstract': 'JP10232696A  PROBLEM TO BE SOLVED: To make possible performing noise code book retrieval at a calculation cost nearly equal to the case using an algebraic structural voice source as a noise code book and obtaining a high quality synthetic voice in a voice source vector generating device and a voice coding/decoding device efficiently compression coding/decoding voice information. SOLUTION: The voice vector generating device makes possible storing (11) plural pieces of fixed waveforms, arranging (12) respective fixed waveforms to respective start end positions based on start end candidate positional information, adding (13) these fixed waveforms, generating a voice source vector (14) and generating the voice source vector close to a rear voice. Further, by constituting a CELP(code excited linear prediction) type voice coding/decoding device using the voice source vector generating device as the noise code book, the quality in the synthetic voice is improved at the calculation cost nearly equal to the case using the algebraic structural voice source as the noise code book.'}

# %%
bib_results["Families"][1]
# Out:
# {'Record': '2',
#  'Family': '51062060',
#  'PatentNumber': 'JP3174742U',
#  'ProbableAssignee': 'YANG FUMIHIRO',
#  'FirstInventor': '',
#  'Publications': [{'PN': 'JP3174742',
#    'KD': 'U',
#    'CC': 'JP',
#    'PD': '20120405',
#    'AN': 'JP20120000304U',
#    'AD': '20120124',
#    'UE': '1218',
#    'IMG': 0}],
#  'Priorities': [{'PR': 'JP20120000304U', 'PRD': '20120124'}],
#  'IPC': ['G01B7/00', 'G01B7/30', 'G01D5/165'],
#  'CPC': [],
#  'USC': [],
#  'Assignees': [{'PA': 'YANG FUMIHIRO', 'STD': 'N', 'CCOR': ''}],
#  'Inventors': [],
#  'Title': 'Structure potentiometer',
#  'Abstract': ''}
